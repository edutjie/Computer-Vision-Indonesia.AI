# %% [markdown]
# *Eduardus Tjitrahardja | @edutjie | 2022*

# %% [markdown]
# # Kernel in Computer Vision

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np
# %matplotlib inline

# %%
# Optional
plt.rcParams.update({
    "lines.color": "white",
    "patch.edgecolor": "white",
    "text.color": "white",
    "axes.facecolor": "black",
    "axes.edgecolor": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "grid.color": "grey",
    "figure.facecolor": "black",
    "figure.edgecolor": "black",
    "savefig.facecolor": "black",
    "savefig.edgecolor": "black"})

# %% [markdown]
# ## Loading Images

# %%
curved_lane = mpimg.imread('images/curved_lane.jpeg')
bridge_trees = mpimg.imread('images/bridge_trees_example.jpeg')

print('curved_lane shape: ', curved_lane.shape)
print('bridge_lane shape: ', bridge_trees.shape)
# Out:
# curved_lane shape:  (720, 1280, 3)
# bridge_lane shape:  (720, 1280, 3)

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

ax[0].set_title('Curved Lane', fontsize=20)
ax[0].imshow(curved_lane)

ax[1].set_title('Bridge Trees', fontsize=20)
ax[1].imshow(bridge_trees)

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

curved_lane_gray = cv2.cvtColor(curved_lane, cv2.COLOR_RGB2GRAY)
ax[0].set_title('Curved Lane', fontsize=20)
ax[0].imshow(curved_lane_gray, cmap='gray')

bridge_trees_gray = cv2.cvtColor(bridge_trees, cv2.COLOR_RGB2GRAY)
ax[1].set_title('Bridge Trees', fontsize=20)
ax[1].imshow(bridge_trees_gray, cmap='gray')

plt.show()

# %% [markdown]
# ## Using Sobel Kernel to Extract Edge Features

# %%
sobel_x = np.array([[-1,0,1],
                    [-2,0,2],
                    [-1,0,1]])

sobel_y = np.array([[-1,-2,-1],
                    [0,0,0],
                    [1,2,1]])

sobel_xy = sobel_x * sobel_y

print('sobel_x: \n', sobel_x)
print('\nsobel_y: \n', sobel_y)
print('\nsobel_xy: \n', sobel_xy)
# Out:
# sobel_x:
#  [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]
#
# sobel_y:
#  [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]
#
# sobel_xy:
#  [[ 1  0 -1]
#  [ 0  0  0]
#  [-1  0  1]]

# %%
sobel_name = {0: "X", 1: "Y", 2: "XY"}

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))

for i, sobel in enumerate([sobel_x, sobel_y, sobel_xy]):
    curved_lane_sobel = cv2.filter2D(curved_lane_gray, -1, sobel)
    ax[i, 0].set_title(f'Sobel {sobel_name[i]} - Curved Lane', fontsize=20)
    ax[i, 0].imshow(curved_lane_sobel, cmap='gray')

    bridge_trees_sobel = cv2.filter2D(bridge_trees_gray, -1, sobel)
    ax[i, 1].set_title(f'Sobel {sobel_name[i]} - Bridge Trees', fontsize=20)
    ax[i, 1].imshow(bridge_trees_sobel, cmap='gray')

plt.show()
